# %% [markdown]
# <a href="https://colab.research.google.com/github/marwaashfaq2004-ai/RL/blob/main/Gymnasium_DRL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import pickle
def run(is_training=True, render=False):
    env = gym.make('Acrobot-v1', render_mode='human' if render else None)
    # hyperparameters
    learning_rate_a = 0.1        # alpha aka learning rate
    discount_factor_g = 0.9      # gamma aka discount factor.
    epsilon = 1                  # start episilon at 1 (100% random actions)
    epsilon_decay_rate = 0.0005  # epsilon decay rate
    epsilon_min = 0.05           # minimum epsilon
    divisions = 15               # used to convert continuous state space to discrete space
    # Divide continuous observation space into discrete segments
    th1_cos  = np.linspace(env.observation_space.low[0], env.observation_space.high[0], divisions)
    th1_sin  = np.linspace(env.observation_space.low[1], env.observation_space.high[1], divisions)
    th2_cos  = np.linspace(env.observation_space.low[2], env.observation_space.high[2], divisions)
    th2_sin  = np.linspace(env.observation_space.low[3], env.observation_space.high[3], divisions)
    th1_w    = np.linspace(env.observation_space.low[4], env.observation_space.high[4], divisions)
    th2_w    = np.linspace(env.observation_space.low[5], env.observation_space.high[5], divisions)
    if(is_training):
        # initialize q table to 15x15x15x15x15x15x3 array. 16 = division of 15 plus 1 extra slice
        q = np.zeros((len(th1_cos)+1, len(th1_sin)+1,
                      len(th2_cos)+1, len(th2_sin)+1,
                      len(th1_w)+1, len(th2_w)+1,
                      env.action_space.n))
    else:
        f = open('acrobot.pkl', 'rb')
        q = pickle.load(f)
        f.close()
    best_reward = -999999        # track best reward
    rewards_per_episode = []     # list to store rewards for each episode
    i = 0                        # episode counter
    while(True):
        state = env.reset()[0]      # Starting position
        # Convert continuous state to discrete state
        s_i0  = np.digitize(state[0], th1_cos)
        s_i1  = np.digitize(state[1], th1_sin)
        s_i2  = np.digitize(state[2], th2_cos)
        s_i3  = np.digitize(state[3], th2_sin)
        s_i4  = np.digitize(state[4], th1_w)
        s_i5  = np.digitize(state[5], th2_w)
        terminated = False          # True when reached goal
        rewards=0                   # rewards collected per episode
        # Episode
        while(not terminated):
            if is_training and np.random.rand() < epsilon:
                # Choose random action
                action = env.action_space.sample()
            else:
                # Choose best action
                action = np.argmax(q[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, :])
            # Take action
            new_state,reward,terminated,truncated,info = env.step(action) # Fixed: Added 'info'
            # Convert continuous state to discrete space
            ns_i0  = np.digitize(new_state[0], th1_cos)
            ns_i1  = np.digitize(new_state[1], th1_sin)
            ns_i2  = np.digitize(new_state[2], th2_cos)
            ns_i3  = np.digitize(new_state[3], th2_sin)
            ns_i4  = np.digitize(new_state[4], th1_w)
            ns_i5  = np.digitize(new_state[5], th2_w)
            # Update Q table
            if is_training:
                q[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, action] += \
                    learning_rate_a * (
                        reward +
                        discount_factor_g * np.max(q[ns_i0, ns_i1, ns_i2, ns_i3, ns_i4, ns_i5,:]) -
                        q[s_i0, s_i1, s_i2, s_i3, s_i4, s_i5, action]
                    )
            # Set state to new state
            state = new_state
            s_i0 = ns_i0
            s_i1 = ns_i1
            s_i2 = ns_i2
            s_i3 = ns_i3
            s_i4 = ns_i4
            s_i5 = ns_i5
            # Collect rewards
            rewards+=reward
        if rewards>best_reward:
            best_reward = rewards
            # Save Q table to file on new best reward
            if is_training:
                f = open('acrobot.pkl','wb')
                pickle.dump(q, f)
                f.close()
        # Store rewards per episode
        rewards_per_episode.append(rewards)
        # Print stats
        if is_training and i!=0 and i%100==0:
            # Calculate mean reward over the last 100 episodes
            mean_reward = np.mean(rewards_per_episode[len(rewards_per_episode)-100:])
            print(f'Episode: {i}, Epsilon: {epsilon:0.2f}, Best Reward: {best_reward:0.1f}, Mean Rewards {mean_reward:0.1f}')
            # Graph mean rewards
            mean_rewards = []
            for t in range(i):
                # Calculate mean reward over the t-100 episodes
                mean_rewards.append(np.mean(rewards_per_episode[max(0, t-100):(t+1)]))
            plt.plot(mean_rewards)
            plt.savefig(f'acrobot.png')
        elif not is_training:
            print(f'Episode: {i} Rewards: {rewards:0.1f}')
        # Stop, if solved
        if best_reward>env.spec.reward_threshold:
            break
        # Decay epsilon
        epsilon = max(epsilon - epsilon_decay_rate, epsilon_min)
        # Increment episode counter
        i+=1
    env.close()
if __name__ == '__main__': # Fixed: Corrected __name__ to __main__
    run(is_training=True, render=False)
    # run(is_training=False, render=True)
# Out:
# Episode: 100, Epsilon: 0.95, Best Reward: -419.0, Mean Rewards -1915.6
# Episode: 200, Epsilon: 0.90, Best Reward: -395.0, Mean Rewards -1855.6
# Episode: 300, Epsilon: 0.85, Best Reward: -395.0, Mean Rewards -1460.7
# Episode: 400, Epsilon: 0.80, Best Reward: -377.0, Mean Rewards -1227.1
# Episode: 500, Epsilon: 0.75, Best Reward: -305.0, Mean Rewards -1018.5
# Episode: 600, Epsilon: 0.70, Best Reward: -221.0, Mean Rewards -921.5
# Episode: 700, Epsilon: 0.65, Best Reward: -197.0, Mean Rewards -787.9
# Episode: 800, Epsilon: 0.60, Best Reward: -197.0, Mean Rewards -655.0
# Episode: 900, Epsilon: 0.55, Best Reward: -190.0, Mean Rewards -655.5
# Episode: 1000, Epsilon: 0.50, Best Reward: -190.0, Mean Rewards -518.0
# Episode: 1100, Epsilon: 0.45, Best Reward: -190.0, Mean Rewards -580.0
# Episode: 1200, Epsilon: 0.40, Best Reward: -190.0, Mean Rewards -569.6
# Episode: 1300, Epsilon: 0.35, Best Reward: -190.0, Mean Rewards -530.1
# Episode: 1400, Epsilon: 0.30, Best Reward: -183.0, Mean Rewards -461.0
# Episode: 1500, Epsilon: 0.25, Best Reward: -183.0, Mean Rewards -537.3
# Episode: 1600, Epsilon: 0.20, Best Reward: -183.0, Mean Rewards -532.0
# Episode: 1700, Epsilon: 0.15, Best Reward: -183.0, Mean Rewards -487.5
# Episode: 1800, Epsilon: 0.10, Best Reward: -182.0, Mean Rewards -440.6
# Episode: 1900, Epsilon: 0.05, Best Reward: -178.0, Mean Rewards -406.4
# Episode: 2000, Epsilon: 0.05, Best Reward: -176.0, Mean Rewards -439.5
# Episode: 2100, Epsilon: 0.05, Best Reward: -140.0, Mean Rewards -436.1
# Episode: 2200, Epsilon: 0.05, Best Reward: -140.0, Mean Rewards -436.7
# Episode: 2300, Epsilon: 0.05, Best Reward: -140.0, Mean Rewards -455.0
# Episode: 2400, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -425.9
# Episode: 2500, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -436.4
# Episode: 2600, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -443.3
# Episode: 2700, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -405.2
# Episode: 2800, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -424.1
# Episode: 2900, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -412.0
# Episode: 3000, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -392.7
# Episode: 3100, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -412.0
# Episode: 3200, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -424.2
# Episode: 3300, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -407.9
# Episode: 3400, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -418.2
# Episode: 3500, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -410.1
# Episode: 3600, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -398.2
# Episode: 3700, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -392.5
# Episode: 3800, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -423.2
# Episode: 3900, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -426.2
# Episode: 4000, Epsilon: 0.05, Best Reward: -129.0, Mean Rewards -452.9
# Episode: 4100, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -441.3
# Episode: 4200, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -418.9
# Episode: 4300, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -406.8
# Episode: 4400, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -390.4
# Episode: 4500, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -332.2
# Episode: 4600, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -348.3
# Episode: 4700, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -370.2
# Episode: 4800, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -334.4
# Episode: 4900, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -397.6
# Episode: 5000, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -353.2
# Episode: 5100, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -333.7
# Episode: 5200, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -397.4
# Episode: 5300, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -376.9
# Episode: 5400, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -404.7
# Episode: 5500, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -384.0
# Episode: 5600, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -341.9
# Episode: 5700, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -337.7
# Episode: 5800, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -332.4
# Episode: 5900, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -349.0
# Episode: 6000, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -342.1
# Episode: 6100, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -393.0
# Episode: 6200, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -375.5
# Episode: 6300, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -340.6
# Episode: 6400, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -366.6
# Episode: 6500, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -381.2
# Episode: 6600, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -400.8
# Episode: 6700, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -417.9
# Episode: 6800, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -399.7
# Episode: 6900, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -352.4
# Episode: 7000, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -306.9
# Episode: 7100, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -321.6
# Episode: 7200, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -337.7
# Episode: 7300, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -299.8
# Episode: 7400, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -296.7
# Episode: 7500, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -300.9
# Episode: 7600, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -290.0
# Episode: 7700, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -327.3
# Episode: 7800, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -329.8
# Episode: 7900, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -321.2
# Episode: 8000, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -343.6
# Episode: 8100, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -325.9
# Episode: 8200, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -355.4
# Episode: 8300, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -356.7
# Episode: 8400, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -329.8
# Episode: 8500, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -328.5
# Episode: 8600, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -317.3
# Episode: 8700, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -325.9
# Episode: 8800, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -363.5
# Episode: 8900, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -333.8
# Episode: 9000, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -328.2
# Episode: 9100, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -340.5
# Episode: 9200, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -358.8
# Episode: 9300, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -348.9
# Episode: 9400, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -344.0
# Episode: 9500, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -287.6
# Episode: 9600, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -278.6
# Episode: 9700, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -281.0
# Episode: 9800, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -276.6
# Episode: 9900, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -296.5
# Episode: 10000, Epsilon: 0.05, Best Reward: -111.0, Mean Rewards -295.6
# Episode: 10100, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -289.6
# Episode: 10200, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -325.7
# Episode: 10300, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -348.3
# Episode: 10400, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -330.8
# Episode: 10500, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -317.6
# Episode: 10600, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -276.4
# Episode: 10700, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -276.6
# Episode: 10800, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -310.4
# Episode: 10900, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -344.9
# Episode: 11000, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -296.2
# Episode: 11100, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -306.3
# Episode: 11200, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -291.0
# Episode: 11300, Epsilon: 0.05, Best Reward: -108.0, Mean Rewards -292.7
# Episode: 11400, Epsilon: 0.05, Best Reward: -101.0, Mean Rewards -294.8
# Episode: 11500, Epsilon: 0.05, Best Reward: -101.0, Mean Rewards -316.3
# Episode: 11600, Epsilon: 0.05, Best Reward: -101.0, Mean Rewards -315.6
